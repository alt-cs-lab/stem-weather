# %% [markdown]
# # Google Colab Setup
#
# To use this project in Google Colab, start by running the following code block to clone the repository data and install Python libraries.

# %%
# Clone the repository into Colab
# !git clone https://github.com/alt-cs-lab/stem-weather
# Change the current working directory to the cloned repository
# %cd stem-weather
# Install the required Python libraries
# %pip install -r requirements.txt

# %% [markdown]
# ## Note on Terminal Commands
#
# In Google Colab, all terminal commands must be executed through the notebook's code blocks, not through the terminal. For example, run the code block below to perform the first step of cleaning the data:

# %%
# Clean the Cherokee data set
# !python clean_data.py cherokee.csv

# %% [markdown]
# ---
# # Using Data Science to Analyze the Weather
#
# Start by loading the data into Jupyter. This requires us to read the data from the CSV file, transpose it from columns to rows, and place it in a Pandas dataframe. Let's do that for the Cherokee data!

# %%
# Write code here
print("Hello World")
